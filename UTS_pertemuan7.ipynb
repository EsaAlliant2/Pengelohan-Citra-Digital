# %%
# Di folder project kamu
git init
git add . 
git commit -m "First commit"
git branch -M main
git remote add origin https://github.com/EsaAlliant2/Pengelohan-Citra-Digital/tree/main
git push -u origin main
# Out:
#   Cell In[2], line 2
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
# 1. Tambahkan semua file (termasuk yang baru dan yang dihapus)
# !git add .

# 2. Lakukan commit (simpan perubahan lokal)
# !git commit -m "Update: Add pertemuan 7 notebook"
# !git config --global user.email "email_anda@contoh.com"
# !git config --global user.name "Nama Anda di GitHub"
# !git branch -M main
# !git remote add origin https://github.com/EsaAlliant2/Pengelohan-Citra-Digital/tree/main
# !git push -u origin main
# Out:
# warning: in the working copy of '.ipynb_checkpoints/UTS_pertemuan7-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'UTS_pertemuan7.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main c1d7da0] Update: Add pertemuan 7 notebook
#  2 files changed, 11 insertions(+), 22 deletions(-)
#  rename .ipynb_checkpoints/{UTS-checkpoint.ipynb => UTS_pertemuan7-checkpoint.ipynb} (100%)
#  rename UTS.ipynb => UTS_pertemuan7.ipynb (65%)
# error: remote origin already exists.
# fatal: repository 'https://github.com/EsaAlliant2/Pengelohan-Citra-Digital/tree/main/' not found
