# %%
# Di folder project kamu
git init
git add . 
git commit -m "First commit"
git branch -M main
git remote add origin https://github.com/EsaAlliant2/Pengelohan-Citra-Digital/tree/main
git push -u origin main
# Out:
#   Cell In[2], line 2
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
# !git config --global user.email "email_anda@contoh.com"
# !git config --global user.name "Nama Anda di GitHub"
# !git commit -m "Add initial Jupyter Notebook"
# !git branch -M main
# !git remote add origin https://github.com/EsaAlliant2/Pengelohan-Citra-Digital/tree/main
# !git push -u origin main
# Out:
# [main (root-commit) a5cedb0] Add initial Jupyter Notebook
#  4 files changed, 313 insertions(+)
#  create mode 100644 .ipynb_checkpoints/UTS-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 UTS.ipynb
#  create mode 100644 Untitled.ipynb
# error: remote origin already exists.
# fatal: repository 'https://github.com/EsaAlliant2/Pengelohan-Citra-Digital/tree/main/' not found
