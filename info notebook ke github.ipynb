# %%
# !git remote remove origin

# %%
# !git remote add origin https://github.com/EsaAlliant2/Pengelohan-Citra-Digital.git

# %%
# !git push -u origin main
# Out:
# To https://github.com/EsaAlliant2/Pengelohan-Citra-Digital.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/EsaAlliant2/Pengelohan-Citra-Digital.git'
# hint: Updates were rejected because the remote contains work that you do not
# hint: have locally. This is usually caused by another repository pushing to
# hint: the same ref. If you want to integrate the remote changes, use
# hint: 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin main
# Out:
# From https://github.com/EsaAlliant2/Pengelohan-Citra-Digital
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# fatal: refusing to merge unrelated histories

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# Merge made by the 'ort' strategy.
#  LICENSE          |  21 ++++
#  Pertemuan7.ipynb | 369 +++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  README.md        |   2 +
#  UTS              |   1 +
#  4 files changed, 393 insertions(+)
#  create mode 100644 LICENSE
#  create mode 100644 Pertemuan7.ipynb
#  create mode 100644 README.md
#  create mode 100644 UTS
# From https://github.com/EsaAlliant2/Pengelohan-Citra-Digital
#  * branch            main       -> FETCH_HEAD
# warning: in the working copy of 'UTS_pertemuan7.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git push origin main
# Out:
# To https://github.com/EsaAlliant2/Pengelohan-Citra-Digital.git
#    dbf2888..fb88454  main -> main

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git add .
# Out:
# warning: in the working copy of 'UTS_pertemuan7.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "Deskripsi singkat perubahan saya (perubahan)"
# Out:
# [main e15ce4e] Deskripsi singkat perubahan saya (perubahan)
#  1 file changed, 82 insertions(+), 41 deletions(-)

# %%
# !git push origin main
# Out:
# To https://github.com/EsaAlliant2/Pengelohan-Citra-Digital.git
#    fb88454..e15ce4e  main -> main
